# %% [markdown]
# <a href="https://colab.research.google.com/github/hema02004/Data-Mining/blob/main/exp-4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
df = pd.read_csv("/content/kc_house_data.csv")

# %%
# Display the first few rows of the DataFrame
df.head(20)
# Create a figure with two subplots for histograms
fig = plt.figure(figsize=(12, 6))
sqft = fig.add_subplot(121) # Subplot for square footage histogram
cost = fig.add_subplot(122) # Subplot for housing prices histogram
# Plot the histogram for square footage
sqft.hist(df.sqft_living, bins=80)
sqft.set_xlabel('Ft^2')
sqft.set_title("Histogram of House Square Footage")
# Plot the histogram for housing prices
cost.hist(df.price, bins=80)
cost.set_xlabel('Price ($)')
cost.set_title("Histogram of Housing Prices")
# Show the histograms
plt.show()
# Fit a linear regression model using statsmodels
m = ols('price ~ sqft_living', df).fit()
print(m.summary())
# Plot a jointplot with a regression line using seaborn
sns.jointplot(x="sqft_living", y="price", data=df, kind='reg', height=5)
plt.show()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.492
# Model:                            OLS   Adj. R-squared:                  0.492
# Method:                 Least Squares   F-statistic:                 1.844e+04
# Date:                Mon, 01 Apr 2024   Prob (F-statistic):               0.00
# Time:                        07:14:25   Log-Likelihood:            -2.6426e+05
# No. Observations:               19023   AIC:                         5.285e+05
# Df Residuals:                   19021   BIC:                         5.285e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept   -4.939e+04   4696.088    -10.517      0.000   -5.86e+04   -4.02e+04
# sqft_living   284.5700      2.095    135.809      0.000     280.463     288.677
# ==============================================================================
# Omnibus:                    13201.948   Durbin-Watson:                   1.984
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           519717.914
# Skew:                           2.848   Prob(JB):                         0.00
# Kurtosis:                      27.965   Cond. No.                     5.56e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.56e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
