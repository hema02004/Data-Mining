# %% [markdown]
# <a href="https://colab.research.google.com/github/hema02004/Data-Mining/blob/main/exp-6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
#First, let's construct a small corpus.
corpus = ['data science is one of the most important fields ofscience','this is one of the best data science courses','data scientists analyze data' ]
#Next, we'll create a word set for the corpus:
words_set = set()
for doc in corpus:
  words = doc.split(' ')
  words_set = words_set.union(set(words))
print('Number of words in the corpus:',len(words_set))
print('The words in the corpus: \n', words_set)
# Out:
# Number of words in the corpus: 15
# The words in the corpus:
#  {'the', 'ofscience', 'science', 'this', 'most', 'important', 'courses', 'analyze', 'data', 'fields', 'one', 'is', 'scientists', 'of', 'best'}

# %%
n_docs = len(corpus)
n_words_set=len(words_set)
words_list=list(words_set)
df_tf = pd.DataFrame(np.zeros((n_docs, n_words_set)), columns=words_list)
for i in range(n_docs):
  words = corpus[i].split(' ') # Words in the document
  for w in words:
    df_tf[w][i] = df_tf[w][i] + (1 / len(words))
df_tf
# Out:
#         the  ofscience   science      this  most  important   courses  \
# 0  0.100000        0.1  0.100000  0.000000   0.1        0.1  0.000000
# 1  0.111111        0.0  0.111111  0.111111   0.0        0.0  0.111111
# 2  0.000000        0.0  0.000000  0.000000   0.0        0.0  0.000000
#
#    analyze      data  fields       one        is  scientists        of  \
# 0     0.00  0.100000     0.1  0.100000  0.100000        0.00  0.100000
# 1     0.00  0.111111     0.0  0.111111  0.111111        0.00  0.111111
# 2     0.25  0.500000     0.0  0.000000  0.000000        0.25  0.000000
#
#        best
# 0  0.000000
# 1  0.111111
# 2  0.000000

# %%
print("IDF of: ")
idf = {}
for w in words_set:
  k = 0 # number of documents in the corpus that contain this word
  for i in range(n_docs):
    if w in corpus[i].split():
      k+= 1
      idf[w] = np.log10(n_docs / k)
      print(f'{w:>15}: {idf[w]:>10}')
# Out:
# IDF of:
#             the: 0.47712125471966244
#             the: 0.17609125905568124
#       ofscience: 0.47712125471966244
#         science: 0.47712125471966244
#         science: 0.17609125905568124
#            this: 0.47712125471966244
#            most: 0.47712125471966244
#       important: 0.47712125471966244
#         courses: 0.47712125471966244
#         analyze: 0.47712125471966244
#            data: 0.47712125471966244
#            data: 0.17609125905568124
#            data:        0.0
#          fields: 0.47712125471966244
#             one: 0.47712125471966244
#             one: 0.17609125905568124
#              is: 0.47712125471966244
#              is: 0.17609125905568124
#      scientists: 0.47712125471966244
#              of: 0.47712125471966244
#              of: 0.17609125905568124
#            best: 0.47712125471966244

# %%
df_tf_idf=df_tf.copy()
for w in words_set:
  for i in range(n_docs):
    df_tf_idf[w][i]=df_tf[w][i]*idf[w]
df_tf_idf
# Out:
#         the  ofscience   science      this      most  important   courses  \
# 0  0.017609   0.047712  0.017609  0.000000  0.047712   0.047712  0.000000
# 1  0.019566   0.000000  0.019566  0.053013  0.000000   0.000000  0.053013
# 2  0.000000   0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
#
#    analyze  data    fields       one        is  scientists        of      best
# 0  0.00000   0.0  0.047712  0.017609  0.017609     0.00000  0.017609  0.000000
# 1  0.00000   0.0  0.000000  0.019566  0.019566     0.00000  0.019566  0.053013
# 2  0.11928   0.0  0.000000  0.000000  0.000000     0.11928  0.000000  0.000000
